# %% [markdown]
# <a href="https://colab.research.google.com/github/kiranraou/PYTHON_X/blob/main/Image_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/drive/MyDrive/elon musk.png")
cv2_imshow(img)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_invert = cv2.bitwise_not(img_gray)
img_smooth = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
img_final = cv2.divide(img_gray, 255 - img_smooth, scale=255)
cv2_imshow(img_final)
# Out:
# <PIL.Image.Image image mode=RGB size=487x560 at 0x7F8ACEBC03D0>
# <PIL.Image.Image image mode=L size=487x560 at 0x7F8ACEBC03D0>
